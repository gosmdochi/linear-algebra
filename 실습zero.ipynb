# %% [markdown]
# <a href="https://colab.research.google.com/github/gosmdochi/linear-algebra/blob/main/%EC%8B%A4%EC%8A%B5zero.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("배고파 죽을수도 있을 것 같아")
# Out:
# 배고파 죽을수도 있을 것 같아

# %% [markdown]
# # 1. 파이썬 기초

# %% [markdown]
# ---
# ### 프린트

# %%
print("Hello, world")

# integer
x = 3
print("정수: %01d, %02d, %03d, %04d, %05d" % (x, x, x, x, x))

# float
x = 256.123
print("정수: %01f, %02f, %03f" % (x, x, x))

# string
x = "Hello world"
print("문자역: [%s]" % (x))
# Out:
# Hello, world
# 정수: 3, 03, 003, 0003, 00003
# 정수: 256.123000, 256.123000, 256.123000
# 문자역: [Hello world]

# %% [markdown]
# ---
# ### 반복문, 조건문

# %%
contents = ["Regression", "Classification", "SYM", "Clustering", "Dimension reduction",
            "NN", "CNN", "AE", "GAN", "RNN"]

for con in contents:
  if con in ["Regression", "Classification", "SYM", "Clustering", "Dimension reduction"]:
    print("%s은(는) 기계학습 내용입니다." %con)
  elif con in ["CNN"]:
    print("%s은(는) convolutional neural network 내용입니다." %con)
  else:
    print("%s은(는) 심층학습 내용입니다." %con)
# Out:
# Regression은(는) 기계학습 내용입니다.
# Classification은(는) 기계학습 내용입니다.
# SYM은(는) 기계학습 내용입니다.
# Clustering은(는) 기계학습 내용입니다.
# Dimension reduction은(는) 기계학습 내용입니다.
# NN은(는) 심층학습 내용입니다.
# CNN은(는) convolutional neural network 내용입니다.
# AE은(는) 심층학습 내용입니다.
# GAN은(는) 심층학습 내용입니다.
# RNN은(는) 심층학습 내용입니다.
